# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as snb

# %%
df=pd.read_csv('/content/drive/MyDrive/MLL/salaries_clean.csv')

# %%
df.head()

# %%
df.tail()
# Out:
#      Working_Year    Designation Experience Employment_Status  \
# 602          2022  Data Engineer     Senior                FT
# 603          2022  Data Engineer     Senior                FT
# 604          2022   Data Analyst     Senior                FT
# 605          2022   Data Analyst     Senior                FT
# 606          2022   AI Scientist        Mid                FT
#
#     Employee_Location Company_Size  Remote_Working_Ratio  Salary_USD
# 602                US            M                   100    147044.0
# 603                US            M                   100    120309.0
# 604                US            M                     0    123174.0
# 605                US            M                   100    143225.0
# 606                IN            L                   100    190967.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Working_Year          607 non-null    int64
#  1   Designation           607 non-null    object
#  2   Experience            607 non-null    object
#  3   Employment_Status     607 non-null    object
#  4   Employee_Location     607 non-null    object
#  5   Company_Size          607 non-null    object
#  6   Remote_Working_Ratio  607 non-null    int64
#  7   Salary_USD            607 non-null    float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 38.1+ KB

# %%
df.isnull()
# Out:
#      Working_Year  Designation  Experience  Employment_Status  \
# 0           False        False       False              False
# 1           False        False       False              False
# 2           False        False       False              False
# 3           False        False       False              False
# 4           False        False       False              False
# ..            ...          ...         ...                ...
# 602         False        False       False              False
# 603         False        False       False              False
# 604         False        False       False              False
# 605         False        False       False              False
# 606         False        False       False              False
#
#      Employee_Location  Company_Size  Remote_Working_Ratio  Salary_USD
# 0                False         False                 False       False
# 1                False         False                 False       False
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 602    False
# 603    False
# 604    False
# 605    False
# 606    False
# Length: 607, dtype: bool

# %%
from sklearn.model_selection import train_test_split
feature= df[['Experience', 'Salary_USD']]
target= df['Designation']
X_train, X_test, y_train, y_test = train_test_split(feature, target, test_size=0.2, random_state=42)

# %%
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (485, 2)
# X_test shape: (122, 2)
# y_train shape: (485,)
# y_test shape: (122,)

# %%
plt.subplot(2, 2, 1)
plt.hist(df['Company_Size'], bins=20, color='skyblue', edgecolor='black')
plt.title('Company Size Histogram')
plt.xlabel('Company Size')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')
